# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red","Blue","Green"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %% [markdown]
# # DataFrame

# %%
car_Data = pd.DataFrame({"Car Make": series,"Colour": colours})
car_Data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  Green

# %% [markdown]
# # Import Data

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("export_car_sales.csv", index=False)

# %%
export_car_sales = pd.read_csv("export_car_sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
car_sales.dtypes #Attribute
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([1100,2000,13100])
car_prices.mean(numeric_only=True)
# Out:
# np.float64(5400.0)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].sum() #Specific column operations
# Out:
# np.int64(786014)

# %%
len(car_sales) #Number of Tuples
# Out:
# 10

# %% [markdown]
# # View and Selecting

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(7) #default 5
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### .loc & .iloc

# %%
animals = pd.Series(["cat","dog","panda","snake","bird"],index=[0,3,8,3,9])
animals
# Out:
# 0      cat
# 3      dog
# 8    panda
# 3    snake
# 9     bird
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[3] #Index Location
# Out:
# 'snake'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0      cat
# 3      dog
# 8    panda
# dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 8    panda
# 3    snake
# 9     bird
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]  #Filter
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000].Make
# Out:
# 0    Toyota
# 4    Nissan
# Name: Make, dtype: object

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Group By

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','',regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/r6/5d6v8wt9607_klstd2c5wdv00000gn/T/ipykernel_22843/2786170244.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','',regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# # Manipulating

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean(numeric_only=True)
# Out:
# np.float64(92302.66666666667)

# %%
#car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
# Out:
# /var/folders/r6/5d6v8wt9607_klstd2c5wdv00000gn/T/ipykernel_22843/1871267833.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# ## Column for Series

# %%
seats_column = pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int64
#  5   Seats          5 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 612.0+ bytes

# %%
car_sales.Seats = car_sales.Seats.fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
car_sales["GST_Price"] = car_sales.Price + car_sales.Price*18/100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price
# 0  toyota  White         150043      4   400000    5.0   472000.0
# 1   honda    Red          87899      4   500000    5.0   590000.0
# 2  toyota   Blue          32549      3   700000    5.0   826000.0
# 3     bmw  Black          11179      5  2200000    5.0  2596000.0
# 4  nissan  White         213095      4   350000    5.0   413000.0
# 5  toyota  Green          99213      4   450000    5.0   531000.0
# 6   honda   Blue          45698      4   750000    5.0   885000.0
# 7   honda   Blue          54738      4   700000    5.0   826000.0
# 8  toyota  White          60000      4   625000    5.0   737500.0
# 9  nissan  White          31600      4   970000    5.0  1144600.0

# %%
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price  \
# 0  toyota  White         150043      4   400000    5.0   472000.0
# 1   honda    Red          87899      4   500000    5.0   590000.0
# 2  toyota   Blue          32549      3   700000    5.0   826000.0
# 3     bmw  Black          11179      5  2200000    5.0  2596000.0
# 4  nissan  White         213095      4   350000    5.0   413000.0
# 5  toyota  Green          99213      4   450000    5.0   531000.0
# 6   honda   Blue          45698      4   750000    5.0   885000.0
# 7   honda   Blue          54738      4   700000    5.0   826000.0
# 8  toyota  White          60000      4   625000    5.0   737500.0
# 9  nissan  White          31600      4   970000    5.0  1144600.0
#
#    Number of Wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# 6                 4
# 7                 4
# 8                 4
# 9                 4

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              10 non-null     object
#  1   Colour            10 non-null     object
#  2   Odometer (KM)     10 non-null     int64
#  3   Doors             10 non-null     int64
#  4   Price             10 non-null     int64
#  5   Seats             10 non-null     float64
#  6   GST_Price         10 non-null     float64
#  7   Number of Wheels  10 non-null     int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 772.0+ bytes

# %%
car_sales = car_sales.drop("Number of Wheels", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price
# 0  toyota  White         150043      4   400000    5.0   472000.0
# 1   honda    Red          87899      4   500000    5.0   590000.0
# 2  toyota   Blue          32549      3   700000    5.0   826000.0
# 3     bmw  Black          11179      5  2200000    5.0  2596000.0
# 4  nissan  White         213095      4   350000    5.0   413000.0
# 5  toyota  Green          99213      4   450000    5.0   531000.0
# 6   honda   Blue          45698      4   750000    5.0   885000.0
# 7   honda   Blue          54738      4   700000    5.0   826000.0
# 8  toyota  White          60000      4   625000    5.0   737500.0
# 9  nissan  White          31600      4   970000    5.0  1144600.0

# %%
car_sales["Passed_Road_Safety"] = True
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                10 non-null     object
#  1   Colour              10 non-null     object
#  2   Odometer (KM)       10 non-null     int64
#  3   Doors               10 non-null     int64
#  4   Price               10 non-null     int64
#  5   Seats               10 non-null     float64
#  6   GST_Price           10 non-null     float64
#  7   Passed_Road_Safety  10 non-null     bool
# dtypes: bool(1), float64(2), int64(3), object(2)
# memory usage: 702.0+ bytes

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price  \
# 6   honda   Blue          45698      4   750000    5.0   885000.0
# 3     bmw  Black          11179      5  2200000    5.0  2596000.0
# 8  toyota  White          60000      4   625000    5.0   737500.0
# 9  nissan  White          31600      4   970000    5.0  1144600.0
# 7   honda   Blue          54738      4   700000    5.0   826000.0
# 4  nissan  White         213095      4   350000    5.0   413000.0
# 1   honda    Red          87899      4   500000    5.0   590000.0
# 5  toyota  Green          99213      4   450000    5.0   531000.0
# 0  toyota  White         150043      4   400000    5.0   472000.0
# 2  toyota   Blue          32549      3   700000    5.0   826000.0
#
#    Passed_Road_Safety
# 6                True
# 3                True
# 8                True
# 9                True
# 7                True
# 4                True
# 1                True
# 5                True
# 0                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price  \
# 0  toyota  White         150043      4   400000    5.0   472000.0
# 1   honda    Red          87899      4   500000    5.0   590000.0
# 2  toyota   Blue          32549      3   700000    5.0   826000.0
# 3     bmw  Black          11179      5  2200000    5.0  2596000.0
# 4  nissan  White         213095      4   350000    5.0   413000.0
# 5  toyota  Green          99213      4   450000    5.0   531000.0
# 6   honda   Blue          45698      4   750000    5.0   885000.0
# 7   honda   Blue          54738      4   700000    5.0   826000.0
# 8  toyota  White          60000      4   625000    5.0   737500.0
# 9  nissan  White          31600      4   970000    5.0  1144600.0
#
#    Passed_Road_Safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# ...

# %%
car_sales_shuffled.reset_index(inplace=True,drop=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price  \
# 0   honda   Blue          45698      4   750000    5.0   885000.0
# 1     bmw  Black          11179      5  2200000    5.0  2596000.0
# 2  toyota  White          60000      4   625000    5.0   737500.0
# 3  nissan  White          31600      4   970000    5.0  1144600.0
# 4   honda   Blue          54738      4   700000    5.0   826000.0
# 5  nissan  White         213095      4   350000    5.0   413000.0
# 6   honda    Red          87899      4   500000    5.0   590000.0
# 7  toyota  Green          99213      4   450000    5.0   531000.0
# 8  toyota  White         150043      4   400000    5.0   472000.0
# 9  toyota   Blue          32549      3   700000    5.0   826000.0
#
#    Passed_Road_Safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x : x / 100)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  GST_Price  \
# 0  toyota  White        1500.43      4   400000    5.0   472000.0
# 1   honda    Red         878.99      4   500000    5.0   590000.0
# 2  toyota   Blue         325.49      3   700000    5.0   826000.0
# 3     bmw  Black         111.79      5  2200000    5.0  2596000.0
# 4  nissan  White        2130.95      4   350000    5.0   413000.0
# 5  toyota  Green         992.13      4   450000    5.0   531000.0
# 6   honda   Blue         456.98      4   750000    5.0   885000.0
# 7   honda   Blue         547.38      4   700000    5.0   826000.0
# 8  toyota  White         600.00      4   625000    5.0   737500.0
# 9  nissan  White         316.00      4   970000    5.0  1144600.0
#
#    Passed_Road_Safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# ...
