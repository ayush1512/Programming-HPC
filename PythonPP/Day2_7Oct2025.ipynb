# %% [markdown]
# # Agenda (Day2 : 07Oct2025):
#     - Dynamic-Programming
#     - Profiling, time, timeit
#     - co-routines
#     - decorators
#
#     - Intro towards Parallel-programming(hardware & packages)
#     - MultiThreading.
#     - Multiprocessing.
#     - File-handling and serializing

# %% [markdown]
# ## Dynamic Programming

# %%
def fib(n):
    if n == 0 :
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
        
#### App ###
def main():
    for val in range(5):
        print(f' fib({val}) = { fib(val)}')
        
if __name__ == '__main__':
    main()
# Out:
#  fib(0) = 0
#  fib(1) = 1
#  fib(2) = 1
#  fib(3) = 2
#  fib(4) = 3

# %%
# %timeit main
# Out:
# 37 ns ± 2.1 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
def fib(n):
    if n == 0 :
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
        
#### App ###
def main():
    
    for val in range(5):
        print(f' fib({val}) = { fib(val)}')
        
if __name__ == '__main__':
    import cProfile
    cProfile.run('main()')
# Out:
#  fib(0) = 0
#  fib(1) = 1
#  fib(2) = 1
#  fib(3) = 2
#  fib(4) = 3
#          146 function calls (132 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      19/5    0.000    0.000    0.000    0.000 3148799949.py:1(fib)
#         1    0.000    0.000    0.000    0.000 3148799949.py:10(main)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#        10    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        10    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        10    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#        10    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        10    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        10    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        10    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
def fib(n):
    if n == 0 :
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
        
#### App ###
def main():
    
    for val in range(5):
        print(f' fib({val}) = { fib(val)}', end=", ")
        
if __name__ == '__main__':
    import cProfile
    cProfile.run('main()')
# Out:
#  fib(0) = 0,  fib(1) = 1,  fib(2) = 1,  fib(3) = 2,  fib(4) = 3,          146 function calls (132 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      19/5    0.000    0.000    0.000    0.000 1943692644.py:1(fib)
#         1    0.000    0.000    0.001    0.001 1943692644.py:10(main)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#        10    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        10    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        10    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#        10    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        10    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        10    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        10    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
def fib(n):
    if n == 0 :
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
        
#### App ###
def main():
    
    for val in range(10):
        print(f' fib({val}) = { fib(val)}', end=", ")
        
if __name__ == '__main__':
    import cProfile
    cProfile.run('main()')
# Out:
#  fib(0) = 0,  fib(1) = 1,  fib(2) = 1,  fib(3) = 2,  fib(4) = 3,  fib(5) = 5,  fib(6) = 8,  fib(7) = 13,  fib(8) = 21,  fib(9) = 34,          518 function calls (252 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    276/10    0.000    0.000    0.000    0.000 3491638768.py:1(fib)
#         1    0.000    0.000    0.000    0.000 3491638768.py:10(main)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#        20    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        20    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        20    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#        20    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        20    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        20    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        20    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
def fib(n):
    if n == 0 :
        return 0
    elif n == 1:
        return 1
    else :
        return fib(n-1) + fib(n-2)
        
#### App ###
def main():
    
    for val in range(36):
        print(f' fib({val}) = { fib(val)}', end=", ")
        
if __name__ == '__main__':
    import cProfile
    cProfile.run('main()')
# Out:
#  fib(0) = 0,  fib(1) = 1,  fib(2) = 1,  fib(3) = 2,  fib(4) = 3,  fib(5) = 5,  fib(6) = 8,  fib(7) = 13,  fib(8) = 21,  fib(9) = 34,  fib(10) = 55,  fib(11) = 89,  fib(12) = 144,  fib(13) = 233,  fib(14) = 377,  fib(15) = 610,  fib(16) = 987,  fib(17) = 1597,  fib(18) = 2584,  fib(19) = 4181,  fib(20) = 6765,  fib(21) = 10946,  fib(22) = 17711,  fib(23) = 28657,  fib(24) = 46368,  fib(25) = 75025,  fib(26) = 121393,  fib(27) = 196418,  fib(28) = 317811,  fib(29) = 514229,  fib(30) = 832040,  fib(31) = 1346269,  fib(32) = 2178309,  fib(33) = 3524578,  fib(34) = 5702887,  fib(35) = 9227465,          78183725 function calls (7417 primitive calls) in 44.669 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 78176300/36   44.648    0.000   44.672    1.241 2562634040.py:1(fib)
#         1    0.000    0.000   44.668   44.668 2562634040.py:10(main)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000   44.668   44.668 <string>:1(<module>)
#        44    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#        22    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        22    0.000    0.000    0.031    0.001 asyncio.py:206(_handle_events)
#        11    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#        44    0.000    0.000    0.002    0.000 attrsettr.py:43(__getattr__)
#        44    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#        22    0.000    0.000    0.000    0.000 base_events.py:1947(_add_callback)
#         5    0.000    0.000    0.000    0.000 base_events.py:1957(_timer_handle_cancelled)
#        44    0.001    0.000    0.152    0.003 base_events.py:1962(_run_once)
#        31    0.000    0.000    0.000    0.000 base_events.py:2060(get_debug)
#         5    0.000    0.000    0.000    0.000 base_events.py:457(create_future)
#        21    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#       101    0.000    0.000    0.000    0.000 base_events.py:772(time)
#        16    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#        16    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#         5    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         5    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#        44    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        44    0.000    0.000    0.001    0.000 encoder.py:183(encode)
#        44    0.000    0.000    0.001    0.000 encoder.py:205(iterencode)
#       220    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#       462    0.000    0.000    0.001    0.000 enum.py:1589(_get_value)
#        88    0.000    0.000    0.001    0.000 enum.py:1596(__or__)
#        66    0.000    0.000    0.001    0.000 enum.py:1607(__and__)
#       220    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#        16    0.000    0.000    0.000    0.000 events.py:113(__init__)
#        19    0.000    0.000    0.000    0.000 events.py:129(__lt__)
#         5    0.000    0.000    0.000    0.000 events.py:157(cancel)
#        21    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         5    0.000    0.000    0.000    0.000 events.py:73(cancel)
#        47    0.000    0.000    0.060    0.001 events.py:87(_run)
#         5    0.000    0.000    0.000    0.000 futures.py:310(_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#        44    0.000    0.000    0.000    0.000 hmac.py:117(update)
#        11    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        11    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#        11    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        22    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#        11    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#        15    0.000    0.000    0.005    0.000 ioloop.py:750(_run_callback)
#         5    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         5    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#        23    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#        22    0.000    0.000    0.005    0.000 iostream.py:157(_handle_event)
#        11    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#        11    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#        11    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#        23    0.000    0.000    0.002    0.000 iostream.py:259(schedule)
#        11    0.000    0.000    0.001    0.000 iostream.py:271(send_multipart)
#        11    0.000    0.000    0.002    0.000 iostream.py:276(<lambda>)
#        11    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#        72    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        72    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        72    0.000    0.000    0.001    0.000 iostream.py:577(_schedule_flush)
#        11    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        15    0.000    0.000    0.005    0.000 iostream.py:616(_flush)
#        72    0.001    0.000    0.003    0.000 iostream.py:655(write)
#        26    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        15    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        11    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#        22    0.000    0.000    0.000    0.000 queue.py:115(empty)
#        22    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#        45    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#        44    0.000    0.000    0.004    0.000 selectors.py:304(_select)
#        44    0.001    0.000    0.006    0.000 selectors.py:310(select)
#        11    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#        11    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        11    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        11    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#        11    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#        11    0.000    0.000    0.001    0.000 session.py:649(msg)
#        11    0.000    0.000    0.000    0.000 session.py:675(sign)
#        11    0.000    0.000    0.002    0.000 session.py:690(serialize)
#        11    0.000    0.000    0.003    0.000 session.py:754(send)
#        44    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#       100    0.003    0.000    0.003    0.000 socket.py:626(send)
#        11    0.000    0.000    0.001    0.000 socket.py:703(send_multipart)
#        22    0.000    0.000    0.001    0.000 socket.py:774(recv_multipart)
#        10    0.000    0.000    0.000    0.000 tasks.py:703(sleep)
#        38    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#        38    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#        11    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        11    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#       167    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#       167    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        13    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        13    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#        13    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#        13    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        22    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#        44    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#        22    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#       399    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#        66    0.000    0.000    0.000    0.000 typing.py:426(inner)
#        12    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#        44    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#        22    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#        22    0.000    0.000    0.006    0.000 zmqstream.py:556(_run_callback)
#        22    0.000    0.000    0.027    0.001 zmqstream.py:583(_handle_events)
#        22    0.000    0.000    0.023    0.001 zmqstream.py:624(_handle_recv)
#        22    0.000    0.000    0.001    0.000 zmqstream.py:663(_rebuild_io_state)
#        22    0.000    0.000    0.001    0.000 zmqstream.py:686(_update_handler)
#        11    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFB0FD95050}
#        22    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         5    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        16    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        20    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#        16    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000   44.668   44.668 {built-in method builtins.exec}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        82    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 1242/1198    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       285    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        67    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        36    0.000    0.000    0.003    0.000 {built-in method builtins.print}
#         5    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#        11    0.000    0.000    0.000    0.000 {built-in method now}
#       116    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        44    0.002    0.000    0.004    0.000 {built-in method select.select}
#       101    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        22    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        87    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        29    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        71    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        55    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#        11    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#        11    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        11    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        55    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        72    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        48    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        11    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        38    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        22    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        92    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        44    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        69    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        22    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        47    0.000    0.000    0.052    0.001 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#        44    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        44    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
myFibDB = {}

def fib(n):
    global myFibDB

    if n in myFibDB:
        return myFibDB[n]
        
    if n == 0 :
        myFibDB[n] = 0
    elif n == 1:
        myFibDB[n] = 1
    else :
        myFibDB[n] = fib(n-1) + fib(n-2)
    return myFibDB[n]
        
#### App ###
def main():
    
    for val in range(36):
        print(f' fib({val}) = { fib(val)}', end=", ")
        
if __name__ == '__main__':
    import cProfile
    cProfile.run('main()')
# Out:
#  fib(0) = 0,  fib(1) = 1,  fib(2) = 1,  fib(3) = 2,  fib(4) = 3,  fib(5) = 5,  fib(6) = 8,  fib(7) = 13,  fib(8) = 21,  fib(9) = 34,  fib(10) = 55,  fib(11) = 89,  fib(12) = 144,  fib(13) = 233,  fib(14) = 377,  fib(15) = 610,  fib(16) = 987,  fib(17) = 1597,  fib(18) = 2584,  fib(19) = 4181,  fib(20) = 6765,  fib(21) = 10946,  fib(22) = 17711,  fib(23) = 28657,  fib(24) = 46368,  fib(25) = 75025,  fib(26) = 121393,  fib(27) = 196418,  fib(28) = 317811,  fib(29) = 514229,  fib(30) = 832040,  fib(31) = 1346269,  fib(32) = 2178309,  fib(33) = 3524578,  fib(34) = 5702887,  fib(35) = 9227465,          944 function calls (876 primitive calls) in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 1919141142.py:18(main)
#    104/36    0.000    0.000    0.000    0.000 1919141142.py:3(fib)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#        72    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        72    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        72    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#        72    0.000    0.000    0.001    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        36    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        72    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        72    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        72    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        72    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        72    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
    
    import functools
    
    @functools.lru_cache
    def fib(n):        
        if n == 0 :
            return 0
        elif n == 1:
            return 1
        else :
            return fib(n-1) + fib(n-2)
               
    #### App ###
    def main():
        
        for val in range(36):
            print(f' fib({val}) = { fib(val)}', end=", ")
            
    if __name__ == '__main__':
        import cProfile
        cProfile.run('main()')
# Out:
#  fib(0) = 0,  fib(1) = 1,  fib(2) = 1,  fib(3) = 2,  fib(4) = 3,  fib(5) = 5,  fib(6) = 8,  fib(7) = 13,  fib(8) = 21,  fib(9) = 34,  fib(10) = 55,  fib(11) = 89,  fib(12) = 144,  fib(13) = 233,  fib(14) = 377,  fib(15) = 610,  fib(16) = 987,  fib(17) = 1597,  fib(18) = 2584,  fib(19) = 4181,  fib(20) = 6765,  fib(21) = 10946,  fib(22) = 17711,  fib(23) = 28657,  fib(24) = 46368,  fib(25) = 75025,  fib(26) = 121393,  fib(27) = 196418,  fib(28) = 317811,  fib(29) = 514229,  fib(30) = 832040,  fib(31) = 1346269,  fib(32) = 2178309,  fib(33) = 3524578,  fib(34) = 5702887,  fib(35) = 9227465,          877 function calls (876 primitive calls) in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 1456354646.py:13(main)
#        36    0.000    0.000    0.000    0.000 1456354646.py:3(fib)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#        72    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        72    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        72    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#        72    0.001    0.000    0.001    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#       2/1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        36    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        72    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        72    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        72    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        72    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        72    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# ## Decorators

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y


#### Client / APP #####
def main():
    print(f'add(5,4) = { add(5,4)}')

if __name__ == '__main__':
    main()
# Out:
#  -- add called --
# add(5,4) = 9

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y


#### Client / APP #####
def main():
    print( ' ---- Allocate the resources here!  -------')
    print(f'add(5,4) = { add(5,4)}')
    print( ' ---- Release Allocated the resources here!  -------')
    print("+- "*25)

if __name__ == '__main__':
    main()
# Out:
#  ---- Allocate the resources here!  -------
#  -- add called --
# add(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y


#### Client / APP #####
def main():
    print( ' ---- Allocate the resources here!  -------')
    print(f'add(5,4) = { add(5,4)}')
    print( ' ---- Release Allocated the resources here!  -------')
    print("+- "*25)

    # DRY (Do not Repeat Yourself) principle fails 
    print( ' ---- Allocate the resources here!  -------')
    print(f'add(5,4) = { add(5,4)}')
    print( ' ---- Release Allocated the resources here!  -------')
    print("+- "*25)
    
if __name__ == '__main__':
    main()
# Out:
#  ---- Allocate the resources here!  -------
#  -- add called --
# add(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  ---- Allocate the resources here!  -------
#  -- add called --
# add(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y


### Middle-ware => Framework ###
def render():
    print( ' ---- Allocate the resources here!  -------')
    print(f'add(5,4) = { add(5,4)}')
    print( ' ---- Release Allocated the resources here!  -------')
    print("+- "*25)

#### Client / APP #####
def main():
    render()
    # DRY (Do not Repeat Yourself) principle success 
    render()
    
if __name__ == '__main__':
    main()
# Out:
#  ---- Allocate the resources here!  -------
#  -- add called --
# add(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  ---- Allocate the resources here!  -------
#  -- add called --
# add(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y
def sub(x, y):
    print(' -- sub called --')
    return x - y


### Middle-ware => Framework ###
def render(fn):
    print( ' ---- Allocate the resources here!  -------')
    print(f'fn(5,4) = { fn(5,4)}')
    print( ' ---- Release Allocated the resources here!  -------')
    print("+- "*25)

#### Client / APP #####
def main():
    render(add)
    # DRY (Do not Repeat Yourself) principle success 
    render(sub)
    
if __name__ == '__main__':
    main()
# Out:
#  ---- Allocate the resources here!  -------
#  -- add called --
# fn(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  ---- Allocate the resources here!  -------
#  -- sub called --
# fn(5,4) = 1
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y
    
def sub(x, y):
    print(' -- sub called --')
    return x - y


### Middle-ware => Framework ###
def render(fn):
    def Inner():
        print( ' ---- Allocate the resources here!  -------')
        print(f'fn(5,4) = { fn(5,4)}')
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
    return Inner
#### Client / APP #####
def main():
    summation = render(add)
    print(f'summation = {summation}') 
    # DRY (Do not Repeat Yourself) principle success 
    diff = render(sub)
    print(f'diff = {diff}')
    
if __name__ == '__main__':
    main()
# Out:
# summation = <function render.<locals>.Inner at 0x000001EB27B68E00>
# diff = <function render.<locals>.Inner at 0x000001EB27B69440>

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y
    
def sub(x, y):
    print(' -- sub called --')
    return x - y


### Middle-ware => Framework ###
def render(fn):
    def Inner():
        print( ' ---- Allocate the resources here!  -------')
        print(f'fn(5,4) = { fn(5,4)}')
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
    return Inner
#### Client / APP #####
def main():
    summation = render(add)
    print(f'summation = {summation}') 
    # DRY (Do not Repeat Yourself) principle success 
    diff = render(sub)
    print(f'diff = {diff}')

    summation()
    diff()
    
if __name__ == '__main__':
    main()
# Out:
# summation = <function render.<locals>.Inner at 0x000001EB27B68360>
# diff = <function render.<locals>.Inner at 0x000001EB27B68860>
#  ---- Allocate the resources here!  -------
#  -- add called --
# fn(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  ---- Allocate the resources here!  -------
#  -- sub called --
# fn(5,4) = 1
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y
    
def sub(x, y):
    print(' -- sub called --')
    return x - y


### Middle-ware => Framework ###
def render(fn):
    def Inner(x,y):
        print( ' ---- Allocate the resources here!  -------')
        print(f'fn({x},{y}) = { fn(x,y)}')
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
        # return None    
    return Inner
    
#### Client / APP #####
def main():
    summation = render(add)
    print(f'summation = {summation}') 
    # DRY (Do not Repeat Yourself) principle success 
    diff = render(sub)
    print(f'diff = {diff}')

    print("-- "*25)
    print(f'summation(5,4) = {summation(5,4)}')
    print(f'diff(5,4) = {diff(5,4)}')
    
if __name__ == '__main__':
    main()
# Out:
# summation = <function render.<locals>.Inner at 0x000001EB27B68EA0>
# diff = <function render.<locals>.Inner at 0x000001EB27B6A480>
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  ---- Allocate the resources here!  -------
#  -- add called --
# fn(5,4) = 9
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
# summation(5,4) = None
#  ---- Allocate the resources here!  -------
#  -- sub called --
# fn(5,4) = 1
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
# diff(5,4) = None

# %%
#### Lib ###############
def add(x, y):
    print(' -- add called --')
    return x + y
    
def sub(x, y):
    print(' -- sub called --')
    return x - y


### Middle-ware => Framework ###
def render(fn):
    def Inner(x,y):
        print( ' ---- Allocate the resources here!  -------')
        #print(f'fn({x},{y}) = { fn(x,y)}')
        result = fn(x,y)
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
        return result
        
    return Inner
    
#### Client / APP #####
def main():
    summation = render(add)
    print(f'summation = {summation}') 
    # DRY (Do not Repeat Yourself) principle success 
    diff = render(sub)
    print(f'diff = {diff}')

    print("-- "*25)
    print(f' Main : summation(5,4) = {summation(5,4)}')
    print(f' Main : diff(5,4) = {diff(5,4)}')
    
if __name__ == '__main__':
    main()
# Out:
# summation = <function render.<locals>.Inner at 0x000001EB27B69580>
# diff = <function render.<locals>.Inner at 0x000001EB27B6A8E0>
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  ---- Allocate the resources here!  -------
#  -- add called --
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  Main : summation(5,4) = 9
#  ---- Allocate the resources here!  -------
#  -- sub called --
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  Main : diff(5,4) = 1

# %%
#### Lib ###############

### Middle-ware => Framework ###
def render(fn):
    def Inner(x,y):
        print( ' ---- Allocate the resources here!  -------')
        result = fn(x,y)
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
        return result
        
    return Inner
    
#### Client / APP #####
def main():    
    def add(x, y):
        print(' -- add called --')
        return x + y
        
    summation = render(add)
    print(f'summation = {summation}') 
    print("-- "*25)
    print(f' Main : summation(5,4) = {summation(5,4)}')
    
if __name__ == '__main__':
    main()
# Out:
# summation = <function render.<locals>.Inner at 0x000001EB27B6B560>
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  ---- Allocate the resources here!  -------
#  -- add called --
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  Main : summation(5,4) = 9

# %%
#### Lib ###############

### Middle-ware => Framework ###
def render(fn):
    def Inner(x,y):
        print( ' ---- Allocate the resources here!  -------')
        result = fn(x,y)
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
        return result
        
    return Inner
    
#### Client / APP #####
def main():    
    def add(x, y):
        print(' -- add called --')
        return x + y
        
    print(f'add = {add}')
    add = render(add)
    print(f'add = {add}') 
    print("-- "*25)
    print(f' Main : add(5,4) = {add(5,4)}')
    
if __name__ == '__main__':
    main()
# Out:
# add = <function main.<locals>.add at 0x000001EB27B69440>
# add = <function render.<locals>.Inner at 0x000001EB27B6B880>
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  ---- Allocate the resources here!  -------
#  -- add called --
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  Main : add(5,4) = 9

# %%
#### Lib ###############

### Middle-ware => Framework ###
def render(fn):
    def Inner(x,y):
        print( ' ---- Allocate the resources here!  -------')
        result = fn(x,y)
        print( ' ---- Release Allocated the resources here!  -------')
        print("+- "*25)
        return result
        
    return Inner
    
#### Client / APP #####
def main():    

    @render
    def add(x, y): #add = render(add)
        print(' -- add called --')
        return x + y
        
    print(f'add = {add}')
     
    print("-- "*25)
    print(f' Main : add(5,4) = {add(5,4)}')
    
if __name__ == '__main__':
    main()
# Out:
# add = <function render.<locals>.Inner at 0x000001EB27B6B920>
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  ---- Allocate the resources here!  -------
#  -- add called --
#  ---- Release Allocated the resources here!  -------
# +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +- +-
#  Main : add(5,4) = 9

# %%
def main():
    def Print_Message(msg):
        print(msg)

    src = " We Love India!"
    Print_Message(src)
    
if __name__ == '__main__':
    main()
# Out:
#  We Love India!

# %%
def Star(fn):
    def Inner(msg):
        print("*" * 25)
        fn(msg)
        print("*" * 25)
    return Inner
    
def main():
    @Star
    def Print_Message(msg):
        print(msg)

    src = " We Love India!"
    Print_Message(src)
    
if __name__ == '__main__':
    main()
# Out:
# *************************
#  We Love India!
# *************************

# %%
def Percentage(fn):
    def Inner(msg):
        print("%" * 50)
        fn(msg)
        print("%" * 50)
    return Inner
    
def Star(fn):
    def Inner(msg):
        print("*" * 25)
        fn(msg)
        print("*" * 25)
    return Inner
    
def main():
    @Percentage
    @Star
    def Print_Message(msg):
        print(msg)

    src = " We Love India!"
    Print_Message(src)
    
if __name__ == '__main__':
    main()
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# *************************
#  We Love India!
# *************************
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# ## Python Debugger: pdb

# %%
def Percentage(fn):
    def Inner(msg):
        print("%" * 50)
        fn(msg)
        print("%" * 50)
    return Inner
    
def Star(fn):
    def Inner(msg):
        print("*" * 25)
        fn(msg)
        print("*" * 25)
    return Inner
    
def main():
    @Percentage
    @Star
    def Print_Message(msg):
        print(msg)

    src = " We Love India!"
    Print_Message(src)
    
if __name__ == '__main__':
    import pdb
    pdb.set_trace() # from 3.6 onwards: pdb.breakpoint()
    main()
# Out:
# > c:\users\acer\appdata\local\temp\ipykernel_20472\1258964513.py(26)<module>()
# ipdb>  c
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# *************************
#  We Love India!
# *************************
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
def Percentage(fn):
    def Inner(msg):
        print("%" * 50)
        fn(msg)
        print("%" * 50)
    return Inner
    
def Star(fn):
    def Inner(msg):
        print("*" * 25)
        fn(msg)
        print("*" * 25)
    return Inner
    
def main():
    @Percentage
    @Star
    def Print_Message(msg):
        print(msg)

    src = " We Love India!"
    Print_Message(src)
    
if __name__ == '__main__':
    import pdb
    pdb.set_trace() # from 3.6 onwards: pdb.breakpoint()
    main()
# Out:
# > c:\users\acer\appdata\local\temp\ipykernel_20472\1258964513.py(26)<module>()
# ipdb>  c
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# *************************
#  We Love India!
# *************************
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# ## Co-Routines

# %%
# what's difference between 
# function, routine, sub-routine, co-routine

# %% [markdown]
# ### Generators { Lazy-fetching-Technique }

# %%
############ App ###
def main():
    for i in 10, 20, 30, 40:
        print(f'doJob({i})')
        
if __name__ == '__main__':
    main()
# Out:
# doJob(10)
# doJob(20)
# doJob(30)
# doJob(40)

# %%
tup1 = (10, 20, 30, 40)

############ App ###
def main():
    for i in tup1:
        print(f'doJob({i})')
        
if __name__ == '__main__':
    main()
# Out:
# doJob(10)
# doJob(20)
# doJob(30)
# doJob(40)

# %% [markdown]
# ### in => iter + next

# %%
it = iter(tup1)
it

# %%
next(it) # 10
# Out:
# 10

# %%
next(it), next(it), next(it) # 20, 30, 40
# Out:
# (20, 30, 40)

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 next(it)
#
# StopIteration:

# %% [markdown]
# ### Co-routine

# %%
def CountDown(Count):
    step = 1
    while Count >= 0:
        yield Count
        Count -= step
        
############ App ###
def main():
    for i in CountDown(10):
        print(f'doJob({i})')
        
if __name__ == '__main__':
    main()

# %%
def DataGenerator():
    print(" 1st Data generated")
    yield 10
    print(" 2nd Data generated")
    yield 20
    print(" 3rd Data generated")
    yield 30
    print(" 4th Data generated")
    yield 40,
    #raise StopItertion()
    
############ App ###
def main():
    for i in DataGenerator():
        print(f'doJob({i})')
        print("+- "*25)
    
if __name__ == '__main__':
    main()

# %%
gen = DataGenerator()
gen

# %%
next(gen)

# %%
next(gen)

# %%
next(gen)

# %%
next(gen)

# %%
try:
     next(gen)
     print('--- never executed ---')
except:
    print(' No more data available ')

# %%
def CountDown(Count):
    step = 1
    while Count >= 0:
        yield Count
        Count -= step
        
############ App ###
def main():
    counter = CountDown(4)
    print(f'doJob({next(counter)})')
    print("+- "*25)
    print(f'doJob({next(counter)})')
    print("+- "*25)
    print(f'doJob({next(counter)})')
    print("+- "*25)
    print(f'doJob({next(counter)})')
    print("+- "*25)
    print(f'doJob({next(counter)})')
    print("+- "*25)
    try:
        print(f'doJob({next(counter)})')
        print("+- "*25)
    except:
        print(' Counter completed ')
if __name__ == '__main__':
    main()

# %%
def CountDown(Count):
    step = 1
    while Count >= 0:
        step = yield Count
        Count -= step
        
############ App ###
def main():
    counter = CountDown(500)
    print(f'doJob({next(counter)})') # 500
    print("+- "*25)
    print(f'doJob({counter.send(75)})') # 425
    print("+- "*25)
    print(f'doJob({counter.send(150)})') # 425 - 150 => 275
    print("+- "*25)
    print(f'doJob({counter.send(175)})') # 100
    print("+- "*25)
    print(f'doJob({counter.send(100)})') #0
    print("+- "*25)
    try:
        print(f'doJob({counter.send(1)}') # exception
        print("+- "*25)
    except:
        print(' Counter completed ')
if __name__ == '__main__':
    main()

# %% [markdown]
# # Pythonic-Threading

# %%
import time
import threading

# Child-Thread functions:
def thread_1():
    print(' thread_1 start...')
    print(' Thread ID = ', threading.get_native_id())
    time.sleep(1)
    print(' thread_1 end...')
    
# Main-thread
def main():
    #import threading

    print(' Main ID = ', threading.get_native_id())
    t1 = threading.Thread(target = thread_1)

    t1.start()

    print(" Main waiting for child thread to complete")
    t1.join()
    
if __name__ == '__main__':
    main()

# %%
import os

# Child-Thread functions:
def thread_1():
    print(' thread_1 start...')
    print(' -- Inside-Thread-Function: os.getpid() = ', os.getpid())
    print(' -- Inside-Thread-Function:os.getppid() = ', os.getppid())
    print(' Thread ID = ', threading.get_native_id())
    time.sleep(1)
    print(' thread_1 end...')
    
# Main-thread
def main():
    #import threading

    print(' Main ID = ', threading.get_native_id())
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    
    t1 = threading.Thread(target = thread_1)

    t1.start()

    print(" Main waiting for child thread to complete")
    t1.join()
    
if __name__ == '__main__':
    main()

# %%
import os

# Child-Thread functions:
def thread_1():
    print(' thread_1 start...')
    print(' -- Inside-Thread-Function: os.getpid() = ', os.getpid())
    print(' -- Inside-Thread-Function:os.getppid() = ', os.getppid())
    print(' Thread ID = ', threading.get_native_id())
    time.sleep(15)
    for _ in range(10000):
        pass
    print(' thread_1 end...')
    
# Main-thread
def main():
    #import threading

    print(' Main ID = ', threading.get_native_id())
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    
    t1 = threading.Thread(target = thread_1)

    t1.start()

    print(" Main waiting for child thread to complete")
    return
    #t1.join()
    
if __name__ == '__main__':
    main()

# %% [markdown]
# ## Thread creation as object

# %%
# Main-thread
def create_thread_from_class():
    class MyThread(threading.Thread):
        def __init__(self):
            super().__init__()

        def run(self):
            print(f'This thread-is created as a class-method')
            print(' Thread-ID = ', threading.get_native_id())
    
    #import threading

    print(' Main ID = ', threading.get_native_id())
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    
    t1 = MyThread()

    t1.start()

    print(" Main waiting for child thread to complete")

    t1.join()
    
if __name__ == '__main__':
    create_thread_from_class()

# %%
import os

# Child-Thread functions:
def thread_1(arg):
    print(' thread_1 start...: arg = ', arg)
    print(' -- Inside-Thread-Function: os.getpid() = ', os.getpid())
    print(' -- Inside-Thread-Function:os.getppid() = ', os.getppid())
    print(' Thread ID = ', threading.get_native_id())
    time.sleep(1)
    
    print(' thread_1 end...')
    
# Main-thread
def main():
    #import threading

    print(' Main ID = ', threading.get_native_id())
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    
    t1 = threading.Thread(target = thread_1, args=( (10, 20, 30, 40), ) )

    t1.start()

    print(" Main waiting for child thread to complete")
    
    t1.join()
    
if __name__ == '__main__':
    main()

# %%
import os

# Child-Thread functions:
def thread_1(arg):
    print(' thread_1 start...: arg = ', arg)
    print(' Thread ID = ', threading.get_native_id())
    time.sleep(1)
    
    print(threading.get_native_id(), ' : thread_1 end...')
    
# Main-thread
def main():
    #import threading

    print(' Main ID = ', threading.get_native_id())
    
    t1 = threading.Thread(target = thread_1, args=( (10, 20, 30, 40), ) )
    t2 = threading.Thread(target = thread_1, args=( ([10, 20, 30], ) ))
    t3 = threading.Thread(target = thread_1, args=( ({10, 20}, ) ))
    t4 = threading.Thread(target = thread_1, args=( ({10:"TEN", 20:"TWENTY"}), ) )

    t1.start()
    t2.start()
    t3.start()
    t4.start()

    print(" Main waiting for child thread to complete")
    
    t1.join()
    t2.join()
    t3.join()
    t4.join()
    
if __name__ == '__main__':
    main()

# %%
os.cpu_count(), threading.cpu_count()

# %%
dir(os)

# %%
dir(threading)

# %%
import multiprocessing

# %%
'cpu_count' in dir(multiprocessing)

# %%
os.cpu_count(), multiprocessing.cpu_count()

# %%
import os
import threading 
import time

# Child-Thread functions:
def thread_daemon(arg):
    print(' thread_1 start...: arg = ', arg)
    print(' Thread ID = ', threading.get_native_id())
    Count = 0
    while True:
        time.sleep(1)
        print(" This print message never gets printed ")
        Count += 1
        if Count % 47 == 0:
            break
        
# Main-thread
def main():

    print(' Main ID = ', threading.get_native_id())
    
    t1 = threading.Thread(target = thread_daemon, args=( (10, 20, 30, 40), ) )
    t1.daemon = True
    
    t1.start()
    print(" Main waiting for child thread to complete")
    
    #t1.join() # Once daemon-thread, it's always daemon
    
if __name__ == '__main__':
    main()
# Out:
#  Main ID =  2208
#  thread_1 start...: arg =  (10, 20, 30, 40)
#  Thread ID =  10476
#  Main waiting for child thread to complete
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed
#  This print message never gets printed

# %%
import multiprocessing

# %%
help(multiprocessing)
# Out:
# Help on package multiprocessing:
#
# NAME
#     multiprocessing
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/multiprocessing.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     # Package analogous to 'threading.py' but using processes
#     #
#     # multiprocessing/__init__.py
#     #
#     # This package is intended to duplicate the functionality (and much of
#     # the API) of threading.py but uses processes instead of threads.  A
#     # subpackage 'multiprocessing.dummy' has the same API but is a simple
#     # wrapper for 'threading'.
#     #
#     # Copyright (c) 2006-2008, R Oudkerk
#     # Licensed to PSF under a Contributor Agreement.
#     #
#
# PACKAGE CONTENTS
#     connection
#     context
#     dummy (package)
#     forkserver
#     heap
#     managers
#     pool
#     popen_fork
#     popen_forkserver
#     popen_spawn_posix
#     popen_spawn_win32
#     process
#     queues
#     reduction
#     resource_sharer
#     resource_tracker
#     shared_memory
#     sharedctypes
#     spawn
#     synchronize
#     util
#
# SUBMODULES
#     reducer
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         multiprocessing.context.ProcessError
#             multiprocessing.context.AuthenticationError
#             multiprocessing.context.BufferTooShort
#             multiprocessing.context.TimeoutError
#     multiprocessing.process.BaseProcess(builtins.object)
#         multiprocessing.context.Process
#
#     class AuthenticationError(ProcessError)
#      |  Method resolution order:
#      |      AuthenticationError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.Exception
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(self, /)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, object, /)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(self, object, /)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(self, object, /)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class BufferTooShort(ProcessError)
#      |  Method resolution order:
#      |      BufferTooShort
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.Exception
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(self, /)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, object, /)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(self, object, /)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(self, object, /)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Process(multiprocessing.process.BaseProcess)
#      |  Process(group=None, target=None, name=None, args=(), kwargs={}, *, daemon=None)
#      |
#      |  Method resolution order:
#      |      Process
#      |      multiprocessing.process.BaseProcess
#      |      builtins.object
#      |
#      |  Methods inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __init__(
#      |      self,
#      |      group=None,
#      |      target=None,
#      |      name=None,
#      |      args=(),
#      |      kwargs={},
#      |      *,
#      |      daemon=None
#      |  )
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  close(self)
#      |      Close the Process object.
#      |
#      |      This method releases resources held by the Process object.  It is
#      |      an error to call this method if the child process is still running.
#      |
#      |  is_alive(self)
#      |      Return whether process is alive
#      |
#      |  join(self, timeout=None)
#      |      Wait until child process terminates
#      |
#      |  kill(self)
#      |      Terminate process; sends SIGKILL signal or uses TerminateProcess()
#      |
#      |  run(self)
#      |      Method to be run in sub-process; can be overridden in sub-class
#      |
#      |  start(self)
#      |      Start child process
#      |
#      |  terminate(self)
#      |      Terminate process; sends SIGTERM signal or uses TerminateProcess()
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from multiprocessing.process.BaseProcess:
#      |
#      |  exitcode
#      |      Return exit code of process or `None` if it has yet to stop
#      |
#      |  ident
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  pid
#      |      Return identifier (PID) of process or `None` if it has yet to start
#      |
#      |  sentinel
#      |      Return a file descriptor (Unix) or handle (Windows) suitable for
#      |      waiting for process termination.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from multiprocessing.process.BaseProcess:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  authkey
#      |
#      |  daemon
#      |      Return whether process is a daemon
#      |
#      |  name
#
#     class ProcessError(builtins.Exception)
#      |  Method resolution order:
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.Exception
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(self, /)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, object, /)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(self, object, /)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(self, object, /)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class TimeoutError(ProcessError)
#      |  Method resolution order:
#      |      TimeoutError
#      |      ProcessError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from ProcessError:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.Exception
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(self, /)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, object, /)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(self, object, /)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(self, object, /)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     Array(typecode_or_type, size_or_initializer, *, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared array
#
#     Barrier(parties, action=None, timeout=None) method of multiprocessing.context.DefaultContext instance
#         Returns a barrier object
#
#     BoundedSemaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a bounded semaphore object
#
#     Condition(lock=None) method of multiprocessing.context.DefaultContext instance
#         Returns a condition object
#
#     Event() method of multiprocessing.context.DefaultContext instance
#         Returns an event object
#
#     JoinableQueue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Lock() method of multiprocessing.context.DefaultContext instance
#         Returns a non-recursive lock object
#
#     Manager() method of multiprocessing.context.DefaultContext instance
#         Returns a manager associated with a running server process
#
#         The managers methods such as `Lock()`, `Condition()` and `Queue()`
#         can be used to create shared objects.
#
#     Pipe(duplex=True) method of multiprocessing.context.DefaultContext instance
#         Returns two connection object connected by a pipe
#
#     Pool(processes=None, initializer=None, initargs=(), maxtasksperchild=None) method of multiprocessing.context.DefaultContext instance
#         Returns a process pool object
#
#     Queue(maxsize=0) method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     RLock() method of multiprocessing.context.DefaultContext instance
#         Returns a recursive lock object
#
#     RawArray(typecode_or_type, size_or_initializer) method of multiprocessing.context.DefaultContext instance
#         Returns a shared array
#
#     RawValue(typecode_or_type, *args) method of multiprocessing.context.DefaultContext instance
#         Returns a shared object
#
#     Semaphore(value=1) method of multiprocessing.context.DefaultContext instance
#         Returns a semaphore object
#
#     SimpleQueue() method of multiprocessing.context.DefaultContext instance
#         Returns a queue object
#
#     Value(typecode_or_type, *args, lock=True) method of multiprocessing.context.DefaultContext instance
#         Returns a synchronized shared object
#
#     active_children()
#         Return list of process objects corresponding to live child processes
#
#     allow_connection_pickling() method of multiprocessing.context.DefaultContext instance
#         Install support for sending connections and sockets
#         between processes
#
#     cpu_count() method of multiprocessing.context.DefaultContext instance
#         Returns the number of CPUs in the system
#
#     current_process()
#         Return process object representing the current process
#
#     freeze_support() method of multiprocessing.context.DefaultContext instance
#         Check whether this is a fake forked process in a frozen executable.
#         If so then run code specified by commandline and exit.
#
#     get_all_start_methods() method of multiprocessing.context.DefaultContext instance
#         Returns a list of the supported start methods, default first.
#
#     get_context(method=None) method of multiprocessing.context.DefaultContext instance
#
#     get_logger() method of multiprocessing.context.DefaultContext instance
#         Return package logger -- if it does not already exist then
#         it is created.
#
#     get_start_method(allow_none=False) method of multiprocessing.context.DefaultContext instance
#
#     log_to_stderr(level=None) method of multiprocessing.context.DefaultContext instance
#         Turn on logging and add a handler which prints to stderr
#
#     parent_process()
#         Return process object representing the parent process
#
#     set_executable(executable) method of multiprocessing.context.DefaultContext instance
#         Sets the path to a python.exe or pythonw.exe binary used to run
#         child processes instead of sys.executable when using the 'spawn'
#         start method.  Useful for people embedding Python.
#
#     set_forkserver_preload(module_names) method of multiprocessing.context.DefaultContext instance
#         Set list of module names to try to load in forkserver process.
#         This is really just a hint.
#
#     set_start_method(method, force=False) method of multiprocessing.context.DefaultContext instance
#
# DATA
#     __all__ = ['Array', 'AuthenticationError', 'Barrier', 'BoundedSemaphor...
#
# FILE
#     c:\programdata\anaconda3\lib\multiprocessing\__init__.py

# %%
def OtherProcess_Start():
    print(" Other Process start ---")
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    print(" Other Process end ---")

# Main-Process
def main():
    #import threading

    print("Parent process start")
    print(' Main process ID = ', threading.get_native_id())
    print(' Main Thread: os.getpid() = ', os.getpid())
    print(' Main Thread: os.getppid() = ', os.getppid())
    
    p1 = multiprocessing.Process(target = OtherProcess_Start)

    p1.start()

    print(" Parent process waiting for child-process")
    p1.join()

    print("Parent process end")
    
if __name__ == '__main__':
    main()
# Out:
# Parent process start
#  Main process ID =  2208
#  Main Thread: os.getpid() =  20472
#  Main Thread: os.getppid() =  3272
#  Parent process waiting for child-process
# Parent process end
