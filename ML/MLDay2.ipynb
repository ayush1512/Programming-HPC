# %%
import numpy as np
import pandas as pd

# %%
values = np.random.randint(30,size=(5))
data = {"Number_of_Students":values}
data
# Out:
# {'Number_of_Students': array([16, 24,  9,  7, 26])}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Number_of_Students
# 0                  16
# 1                  24
# 2                   9
# 3                   7
# 4                  26

# %%
# Quantitative Data
data1 = {'Height_cm': [167.5, 182.0, 176.3, 158.9, 170.2]}
# Qualitative Data
data2 = {'Gender': ['Male', 'Female', 'Female', 'Male', 'Male']}
# Ordinal Data
data3 = {'Education_Level': ['Bachelor', 'Master', 'PhD', 'High School', 'Bachelor']}

# %%
df = pd.DataFrame({**data1, **data2, **data3})

# %%
df
# Out:
#    Height_cm  Gender Education_Level
# 0      167.5    Male        Bachelor
# 1      182.0  Female          Master
# 2      176.3  Female             PhD
# 3      158.9    Male     High School
# 4      170.2    Male        Bachelor

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# Unstructured Data
text_data ={"Comments":["This is a sample sentence for HPC studnets.", "AI/ML/Data science is fascinating.", "Python is a versatile language."]}

# %%
df = pd.DataFrame(text_data)
df
# Out:
#                                       Comments
# 0  This is a sample sentence for HPC studnets.
# 1           AI/ML/Data science is fascinating.
# 2              Python is a versatile language.

# %%
import json
json_data = {
    "employees": [
        {"name": "Ram", "age": 30, "city": "New York"},
        {"name": "Sita", "age": 22, "city": "London"},
        {"name": "Laxman", "age": 32, "city": "Chicago"}
    ]
}

# %%
json1 = json.loads(json_data)
df = pd.json_normalize(json1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3539757062.py in <cell line: 0>()
# ----> 1 json1 = json.loads(json_data)
#       2 df = pd.json_normalize(json1)
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
json
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4220561608.py in <cell line: 0>()
# ----> 1 json_1 = json.loads(json_data)
#       2 json_1
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
# Series Data
s = pd.Series([1,2,3], index=['a','b','c'])
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
t = pd.Series([4 ,5,6], index=['d','e','f'])
t
# Out:
# d    4
# e    5
# f    6
# dtype: int64

# %%
df1 = pd.DataFrame({'A':[1,2], 'B1':[3,4]})
df2 = pd.DataFrame({'A':[1,2], 'B2':[5,6]})
df11 = pd.merge(df1, df2, on='A')
df11
# Out:
#    A  B1  B2
# 0  1   3   5
# 1  2   4   6

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df[df['Age'] > 25]['Name']
# Out:
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df[(df['Age'] > 25)&(df['Age']<35)][['Name','Age']]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Age'] = df['Age']+1
df
# Out:
#       Name  Age         City
# 0    Alice   27     New York
# 1      Bob   32  Los Angeles
# 2  Charlie   37      Chicago

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, np.nan, 30, 22],
    "Score": [85, 90, np.nan, 75]
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David  22.0   75.0

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-3394700599.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
#       Name        Age  Score
# 0    Alice  25.000000   85.0
# 1      Bob  25.666667   90.0
# 2  Charlie  30.000000    NaN
# 3    David  22.000000   75.0

# %%
df['Score'].fillna(df['Score'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-3341022251.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Score'].fillna(df['Score'].mean(),inplace=True)
#       Name        Age      Score
# 0    Alice  25.000000  85.000000
# 1      Bob  25.666667  90.000000
# 2  Charlie  30.000000  83.333333
# 3    David  22.000000  75.000000

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda', np.nan, 'Tom', 'Anna'],
    'Age': [28, 22, 35, np.nan, 45, 30, 22],
    'Salary': [50000, 54000, np.nan, 66000, 71000, 58000, 54000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age   Salary
# 0   John  28.0  50000.0
# 1   Anna  22.0  54000.0
# 2  Peter  35.0      NaN
# 3  Linda   NaN  66000.0
# 4    NaN  45.0  71000.0
# 5    Tom  30.0  58000.0
# 6   Anna  22.0  54000.0

# %%
df['Salary'].fillna(df['Salary'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-2738737218.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].mean(),inplace=True)

# %%
df
# Out:
#     Name   Age        Salary
# 0   John  28.0  50000.000000
# 1   Anna  22.0  54000.000000
# 2  Peter  35.0  58833.333333
# 3  Linda   NaN  66000.000000
# 4    NaN  45.0  71000.000000
# 5    Tom  30.0  58000.000000
# 6   Anna  22.0  54000.000000

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-2368695939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
#     Name        Age        Salary
# 0   John  28.000000  50000.000000
# 1   Anna  22.000000  54000.000000
# 2  Peter  35.000000  58833.333333
# 3  Linda  30.333333  66000.000000
# 4    NaN  45.000000  71000.000000
# 5    Tom  30.000000  58000.000000
# 6   Anna  22.000000  54000.000000

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Name        Age        Salary
# 0   John  28.000000  50000.000000
# 1   Anna  22.000000  54000.000000
# 2  Peter  35.000000  58833.333333
# 3  Linda  30.333333  66000.000000
# 5    Tom  30.000000  58000.000000
# 6   Anna  22.000000  54000.000000

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David","Simran","Simon"],

    "Score": [85, 90, 90, 75,75,75]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     90
# 3    David     75
# 4   Simran     75
# 5    Simon     75

# %%
df['Name'][1] = 'Alice'
# Out:
# /tmp/ipython-input-299369443.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Name'][1] = 'Alice'
# /tmp/ipython-input-299369443.py:1: SettingWithCopyWarning:
# ...

# %%
df.drop_duplicates(subset=['Name'],inplace=True,keep=False)

# %%
df
# Out:
#       Name  Score
# 2  Charlie     90
# 3    David     75
# 4   Simran     75
# 5    Simon     75

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# Independent Variables
X = df.iloc[:,:-1].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
# Dependent Variables
Y = df.iloc[:,-1].values
Y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
# Handling Missing Values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
imputer.fit(X[:,1:3])
X[:,1:3] = imputer.transform(X[:,1:3])
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, 63777.77777777778],
#        ['France', 35.0, 58000.0],
#        ['Spain', 38.77777777777778, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
#Splitting of data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

# %%
X,Y
# Out:
# (array([['France', 44.0, 72000.0],
#         ['Spain', 27.0, 48000.0],
#         ['Germany', 30.0, 54000.0],
#         ['Spain', 38.0, 61000.0],
#         ['Germany', 40.0, 63777.77777777778],
#         ['France', 35.0, 58000.0],
#         ['Spain', 38.77777777777778, 52000.0],
#         ['France', 48.0, 79000.0],
#         ['Germany', 50.0, 83000.0],
#         ['France', 37.0, 67000.0]], dtype=object),
#  array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#        dtype=object))

# %%
X_train,Y_train
# Out:
# (array([['Germany', 40.0, 63777.77777777778],
#         ['France', 37.0, 67000.0],
#         ['Spain', 27.0, 48000.0],
#         ['Spain', 38.77777777777778, 52000.0],
#         ['France', 48.0, 79000.0],
#         ['Spain', 38.0, 61000.0],
#         ['France', 44.0, 72000.0],
#         ['France', 35.0, 58000.0]], dtype=object),
#  array(['Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes'], dtype=object))

# %%
X_test,Y_test
# Out:
# (array([['Germany', 30.0, 54000.0],
#         ['Germany', 50.0, 83000.0]], dtype=object),
#  array(['No', 'No'], dtype=object))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
labelencoder=LabelEncoder()
X[:,0]=labelencoder.fit_transform(X[:,0])
X
# Out:
# array([[0, 44.0, 72000.0],
#        [2, 27.0, 48000.0],
#        [1, 30.0, 54000.0],
#        [2, 38.0, 61000.0],
#        [1, 40.0, 63777.77777777778],
#        [0, 35.0, 58000.0],
#        [2, 38.77777777777778, 52000.0],
#        [0, 48.0, 79000.0],
#        [1, 50.0, 83000.0],
#        [0, 37.0, 67000.0]], dtype=object)

# %%
#onehotencoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder='passthrough')
X=np.array(ct.fit_transform(X))
X
# Out:
# array([[1.0, 0.0, 0.0, 44.0, 72000.0],
#        [0.0, 0.0, 1.0, 27.0, 48000.0],
#        [0.0, 1.0, 0.0, 30.0, 54000.0],
#        [0.0, 0.0, 1.0, 38.0, 61000.0],
#        [0.0, 1.0, 0.0, 40.0, 63777.77777777778],
#        [1.0, 0.0, 0.0, 35.0, 58000.0],
#        [0.0, 0.0, 1.0, 38.77777777777778, 52000.0],
#        [1.0, 0.0, 0.0, 48.0, 79000.0],
#        [0.0, 1.0, 0.0, 50.0, 83000.0],
#        [1.0, 0.0, 0.0, 37.0, 67000.0]], dtype=object)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X1=sc.fit_transform(X)
X1
# Out:
# array([[ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#          7.58874362e-01,  7.49473254e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#         -1.71150388e+00, -1.43817841e+00],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#         -1.27555478e+00, -8.91265492e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#         -1.13023841e-01, -2.53200424e-01],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#          1.77608893e-01,  6.63219199e-16],
#        [ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#         -5.48972942e-01, -5.26656882e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#          0.00000000e+00, -1.07356980e+00],
#        [ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#          1.34013983e+00,  1.38753832e+00],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#          1.63077256e+00,  1.75214693e+00],
# ...

# %%
pe = pd.read_csv('data1.csv')
pe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
pe.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x=pe.iloc[:,:-1].values
y=pe.iloc[:,-1].values

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='black')
plt.plot(x_train,regressor.predict(x_train),color='red')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
#testing ploting
plt.scatter(x_test,y_test,color='black')
plt.plot(x_train,regressor.predict(x_train),color='red')

# %%
#regression coeficient
print(regressor.coef_)
# Out:
# [9312.57512673]

# %%
#y_intercepts
print(regressor.intercept_)
# Out:
# 26780.09915062818
